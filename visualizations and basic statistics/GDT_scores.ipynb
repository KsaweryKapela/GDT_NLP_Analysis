# %%
import sys
import dotenv
import os
dotenv.load_dotenv()
sys.path.append(os.getenv('MAINDIR'))
from helpers.ds_helpers import open_and_prepare_df
import matplotlib.pyplot as plt
import numpy as np

# %%
df = open_and_prepare_df('main')
# Out:
# 522
# 502
# 469
# 417

# %%
len(df[df['GDT_score'] == 4])
# Out:
# 131

# %%
np.mean(df['GDT_score']), np.std(df['GDT_score'])
# Out:
# (7.402877697841727, 3.679718392794481)

# %%
plt.rcParams["font.family"] = "Times New Roman"

# %%
plt.figure(figsize=(8, 6), dpi=100)
ax = plt.axes()

plt.hist(df['GDT_score'], bins=16, linewidth=2, color='#0504aa', alpha=0.7, rwidth=0.95, orientation='horizontal')
plt.ylabel('GDT score', fontsize=14)
ax.set_ylim(3.8, 20.2)
ax.set_yticks(range(4, 20, 2))
ax.set_yticks(range(4, 20, 1), minor=True)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
plt.xlabel('Number of samples', fontsize=14)
plt.grid(axis='x', alpha=0.75)
plt.show()
