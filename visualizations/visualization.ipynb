# %%
import sys
import dotenv
import os
dotenv.load_dotenv()
sys.path.append(os.getenv('MAINDIR'))
from helpers.ds_helpers import open_and_prepare_df
import matplotlib.pyplot as plt
import scienceplots

# %%
df = open_and_prepare_df('main')

# %%
plt.rcParams["font.family"] = "Times New Roman"

# %%
plt.figure(figsize=(8, 6), dpi=100)
ax = plt.axes()

plt.hist(df['GDT_score'], bins=16, linewidth=2, color='#0504aa', alpha=0.7, rwidth=0.95)
plt.xlabel('GDT score', fontsize=14)
ax.set_xlim(3.8, 20.2)
ax.set_xticks(range(4, 20, 2))
ax.set_xticks(range(4, 20, 1), minor=True)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.tick_params(axis='both', which='minor', labelsize=14)
plt.ylabel('Number of samples', fontsize=14)
plt.grid(axis='y', alpha=0.75)
plt.show()
