# %%
from helpers import open_and_prepare_df
import matplotlib.pyplot as plt

# %%
df = open_and_prepare_df('main')

# %%
plt.rcParams["font.family"] = "Times New Roman"

# %%
plt.figure(figsize=(8, 6), dpi=100)
plt.hist(df['GDT_score'], bins=16, linewidth=2, color='#0504aa', alpha=0.7, rwidth=0.95)
plt.xlabel('GDT score', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('GDT scores distribution', fontsize=14)
plt.grid(axis='y', alpha=0.75)
plt.show()
